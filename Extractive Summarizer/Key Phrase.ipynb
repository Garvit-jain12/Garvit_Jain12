# %% [markdown]
# # KEY PHRASE EXTRACTOR (SUMMARIZER)

# %%
# !pip install -U spacy 2.2.0
# !python -m spacy download en_core_web_md

# %%
f=open("IL-Roscoe-Kickapoo_Tenant_Lease_-_Executed_FE_Lease_Supplement_with_VZW_20160920.pdf.txt", "r")
line=f.readline()
f.close()

# %%
f=open("IL-Roscoe-Kickapoo_Tenant_Lease_-_Executed_FE_Lease_Supplement_with_VZW_20160920.pdf.txt", "r")
text=f.read()
#text

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from string import punctuation

# %%
stopwords = list(STOP_WORDS)

# %%
import en_core_web_md
nlp = en_core_web_md.load()

# %%
doc =nlp(text)
#print(doc)

# %%
tokens =[token.text for token in doc]
punctuation = punctuation + '\n'
#print(tokens)
#punctuation

# %%
word_frequencies = {}
for word in doc:
    if word.text.lower() not in stopwords:
        if word.text.lower() not in punctuation:
            if word.text not in word_frequencies.keys():
                word_frequencies[word.text]=1
            else:
                word_frequencies[word.text]+=1
#word_frequencies

# %%
max_frequency=max(word_frequencies.values())
max_frequency
# Out:
# 244

# %%
for word in word_frequencies.keys():
    word_frequencies[word]=word_frequencies[word]/max_frequency

# %%
#print(word_frequencies)

# %%
sentence_tokens= [sent for sent in doc.sents]
#print(sentence_tokens)

# %%
sentence_scores={}
for sent in sentence_tokens:
    for word in sent:
        if word.text.lower() in word_frequencies.keys():
            if sent not in sentence_scores.keys():
                sentence_scores[sent]=word_frequencies[word.text.lower()]
            else:
                sentence_scores[sent] +=word_frequencies[word.text.lower()]
#sentence_scores

# %%
from heapq import nlargest

# %%
#a=0
#select_length = int(len(sentence_tokens)*a)
#select_length
#summary=nlargest(select_length,sentence_scores,key=sentence_scores.get)
#summary=nlargest(select_length,sentence_scores,key=sentence_scores.get)
#final_summary=[word.text for word in summary]
#final_summary

# %%
Percentage=0.2

# %%
a=0
summary=''
while(len(summary)/len(text)<=Percentage):
    a=a+0.001
    select_length=int(len(sentence_tokens)*a)
    summary=nlargest(select_length,sentence_scores,key=sentence_scores.get)
    final_summary=[word.text for word in summary]
    summary = ' '.join(final_summary)

# %%
print(summary)
# Out:
# An easement from the Leased Premises to an open and improved public road in a minimum width
# of either 25 feet or the minimum width necessary to comply with any applicable governmental
# requirements, whichever is greater, to allow for ingress to and egress from the Leased Premises by
# vehicle, and to allow for the installation of utilities to service the Leased Premises
#
# (ii) if required by governmental authorities, an easement for a “Fall Zone” centered on the location of
# the Lessee's tower and extending outward in a circle for the number of feet as may be required by local
# zoning authorities (typically equal to the height of the Lessee’s tower but could be more); and
#
# each to be determined by survey, and upon completion of survey, shall replace this Exhibit “B”,
#
# Lessee acknowledges that Lessor does not own PIN 13-07-300-019 and All notices required or permitted under this Agreement shall be in writing and
# shall be deemed effective upon personal delivery, or three (3) days after being deposited in the U.S. Mail,
# registered or certified, and postage prepaid, or one (1) day after being deposited with a recognized overnight
# delivery service, Such notices shall be addressed to the applicable party at its address shown below, or at
# such other address or addresses as either party shall designate to the other in writing in accordance with this
#
# paragraph:
#
#  Lessor agrees that the terms of this Lease shall be strictly confidential and that
#
# Lessor shall not disclose any of the terms hereof to any third party, except with Lessee's prior written
# consent, Notwithstanding the foregoing, Lessor is permitted 10 disclose the terms of this Lease to its
#
# attomeys, financia) consultants, accountants and lenders.
#
#  THIS GROUND LEASE AGREEMENT (ihe “Lease") is made this t day of
# espe , 2016 (the “Commencement Date”), by and between Shane Land LLC, an
# Dlinois limited Hability company (“Lessor”), and PI TOWER DEVELOPMENT LLC, a Delaware
#
# limited liability company (“Lessee”).
#
#  ,
# as of
#
# 1,
#
# certify that 3
#
# personally came before me this day and acknowledged that (s)he
#
# executed the foregoing instrument. Blt’ ich shall 'be
#
# considered one and the same agreement and shall become effective when one or more counterparts have
#
# been signed by each of the parties, it béing understood that all parties need not sign the same counterpart.
#
#  y Le EXHIBIT “A-1”
#
# Survey or Site Plan
#
# Location of the Leased Premises shall be determined by survey, and upon completion shall replace this
# Exhibit “A-1”.
#
#
#
#
#
#
#
#
#
#
#  This Lease shall run with the Leased Premises described on
# Exhibit “A” and shall be binding upon and inure to the benefit of the parties, their respective heirs,
#
# Successors, personal representatives and assigns.
#
#  Lessee shall be entitled to file its own claims against the condemning authority for the value of
# its Tower Facilities, moving expenses, prepaid rent and business dislocation expenses, A sale of all or part
# of the Leased Premises and/or Easement(s) to a purchaser with the power of eminent domain, in the face of
# the exercise of eminent domain power, shall be treated as taking by condemnation for the purpose of this
#
# paragraph,
#
# 17, Insurance. Such interference shall be deemed a material breach by Lessor, and Lessee shall bave the right, in
# addition to any other rights that it may have in law or equity, to enjoin such interference or {o terminate this
#
# Lease.
#
#  Lessee shall not use said parcel
# for any use EXHIBIT “Cc”
#
# Liens and Encumbrances
#
# Holder of 1" Mortgage:
#  , Edwards, IL 61528 (“Site”), as more particularly described on Exhibit
# “A” and the survey or site plan shown on Exhibit “A-1” attached hereto and made a part hereof (“Leased
# Premises”), together with an easement, or easements, for ingress, egress and utilities, and a “Fall Zone” (if
# applicable) for the duration of the Lease, across the Site and other parcels owned by Lessor with PINs: The Lease provides that during the term of the Lease, in the event that the Lessor receives and
# desires to accept a bona fide offer to sell and convey the Leased Premises to a third party not related to the
# Lessor by at least 51% common ownership, then the Lessor shall first provide the Lessee with a written
# offer to sell and convey the Leased Premises to Lessee upon the same terms and conditions as the offer
# made by the third party, and Lessee shall have twenty (20) business days in which to accept the offer.
#
#  Lessor agrees to be solely responsible for payment of any
# penalties, roll-back or additional taxes, special assessments or other monetary amounts now or hereafter
# payable to any county, city, state or other party as a result of the breach of any conservation use tax program
# affecting the property on which the Leased Premises and Easement(s) are located or resulting from the
# change in the nature or character of the use of the property from its present use to a communications tower
#
# facility.
#
#  By either party upon a default of any covenant or term hereof by the other party,
# which default is not cured within sixty (60) days of receipt of written notice of default (without however,
# limiting any other rights available to the parties pursuant to any other provisions hereof); provided, that if
# the defaulting party commences efforts to cure the default within such period and diligently pursues curing of the default to completion within a reasonable time period, the non-defaulting party shall no longer be
# entitled to declare a default;
#
# (db) In the event the Leased Premises
# and/or Easement(s) are encumbered by a Mortgage on the Commencement Date, Lessor, no later than ten
# (10) days after the Commencement Date, shall obtain and furnish Lessee with a non-disturbance agreement
#
# in recordable form from the holder of each Mortgage.
#
#  Upon assignment of al! of its rights pursuant to this Lease, and the
# execution of a written assumption of all of the terms and conditions of the Lease by the assignee, Lessee
#
# shall be released from any further liability under this Lease.
#
#  In the event such
# defects are not cured to Lessee’s satisfaction, Lessee shall have the right to terminate this Lease upon written
#
# notice to Lessor.
#
#  Lessor an annual rental
# to be paid in equal monthly installments of| “Rent"},
#
# which shall be deemed to include any applicable State, County or local sales or use tax; provided, however,
# that Lessee shall be responsible for any transfer tax due, if any. but
#
# not limited {o antennas, dishes, cabling, additional storage buildings or equipment shelters as are reasonably
# required for the operation and maintenance of the communications equipment, together with rights of
# ingress and egress to the Leased Premises and the right to install utilities to and on the Leased Premises and
# Easement(s) as if said licensee or sublessee were the Lessee under this Lease.
#
#  As used in this Lease, the tenn
# “Hazardous Materials” shall mean any hazardous or toxic substance, material or waste which is, or becomes
# designated as such in the future or is regulated by any agency of the United States Government or by any
# state or local governmental authority having jurisdiction, including, without limitation, any substance,
# material or waste that is defined or designated as a hazardous substance pursuant to the Comprehensive
# Environmental Response, Compensation and Liability Act, the Resource Conservation and Recovery Act,
# the Clean Water Act, or any similar federal, state, or local law, During the Term of this Lease, Lessee shall
# cause the presence, use, storage and/or disposal of any Hazardous Material, on or
# by Lessee, its agents, employees, business invitees, contractors or sublessees £0
# applicable laws, rules, regulations and orders. 3, In the event an Exhibit | is attached — describing the PreinseS, aie LESSEE shall have
# the right to survey the Premises and said survey shall then become Exhibit 2 which shall be attached
# hereto and made a part hereof and shail contro] in the event of any discrepancies between it and
# Exhibit 1. The legal
# description of the Leased Premises shall be determined by survey and shall thereafter replace this Exhibit
# “AY.
#
#  Provided that construction of the
# Tower Facilities (as hereinafter defined) has not commenced, it is understood that Lessee shall have the
# right to terminate this Lease for any reason or no reason at all, without any further lability or obligation to
# Lessor except those obligations which specifically survive the expiration or termination of this Lease, by
# delivery of written notice of termination to Lessor prior 10 the Rent Commencement Date.
#
#  (collectively referred to as a “Mortgage”) made by Lessor which may
# now or bereafler encumber the Leased Premises and Easement(s), provided that no such subordination shal}
# be effective unless the holder of every such Mortgage shall in a separate agreement with Lessee agree that in the event of a foreclosure, or conveyance in licu of foreclosure of Lessor’s interest in the Leased Premises
# and Easement(s), such holder shal} recognize and confirm the validity and existence of this Lease and that
# Lessee shall have the right to continue its use and occupancy of the Leased Premises and Easement(s) in
# accordance with the provisions of this Lease as long as Lessce is not in default of this Lease beyond
# applicable notice and cure periods. If either Lessor or Lessee is represented by a broker in this transaction, that party
# shall be fully responsible for any fees due such broker and shall hold the other party harmless from any
#
#  The Lessor agrees that any property of the Lessee that remains on the Leased
# Premises after ninety (90) days following the expiration or earlier termination of this Lease may be removed
# by the Lessor and, Lessee shall be responsible for reimbursement to Lessor for the reasonable cost of the
# removal of such improvements and restoration of the property to the extent required by this section 11 (a).
#
#  The Initial Term and each Renewal Term shall collectively be referred to herein as the “Term”.
#
#  The policy of general liability insurance shall provide
# a combined single limit of $1,000,000 and shall name Lessor as an additional insured,
#
#  The “Rent Commencement Date” shall mean the date the Lessee commences construction of the
# Tower Facilities; provided, however, in the event that Lessee has not commenced construction of the Tower
# Facilities within two (2) years following the Commencement Date, this Lease shal] automatically terminate
# and the parties shail be released from further liability or obligation hereunder except those obligations which
# ifically survive the expiration or termination of this Lease. Right of First Refusal, in the event that the Lessor receives and desires to accept a bona
#
# fide offer to sell and convey the Leased Premises to a third party not related toahi é Lessor by at least 51%
# common ownership then the Lessor shall first provide the Lessee witha a biter to sell and convey the
# by the third party. For the sake of clarification, the unlimited loading capacity
# does not apply to any second RAD center utilized by LESSEE pursuant to 10a
#
# above.
#
#  Print Name:
#
#
#
#
#
# STATE OF
#
# COUNTY OF
#
# a Notary Public of the County and State aforesaid In the event any such interference does not cease or is not promptly
# rectified, Lessor acknowledges that continuing interference will cause irreparable injury to Lessee, and
# Lessee shall have the right, in addition to any other rights that it may have at Jaw or in equity, to bring
# action to enjoin such interference or to terminate this Lease immediately upon notice to Lessor.
#
#  Conuacis Administrator
#
# Site Nase; IL-Edwards-Kickapoo
#
#  Rd
#
# Edwards County State:
#
#  In the event the date of commencing installation of equipment is
# determinative and such date falls between the Ist and 15th of the month; the Supplement shall
# commence on the Ist of that month and if such date falls between the 16th and 31st of the
#
#
#
# Date or see a written sy bes LES “confirming ‘the Commencement ‘Date, if such an
# acknowledgement ....is required, .. see 's; use of the, Leased Fremiges (th “Governmental
#
# Approval’ >»
#
#
#
#
#
# g
#
#
#
# fob ts
#
#
#
# 5. (c) Lessor shall have the right to assign this Lease without the prior written consent of Lessee, but with written notice to Lessee.
#
#  The substantially prevailing party in any ligation arising hereunder shall be
# entitled 10 its reasonable attorney's fees and court cosis, including appeals and post-judgment proceedings,
#
#  The
# rent set forth in each Supplement shall escalate annually on the first anniversary of the
# Commencement Date of the Supplement and upon each anniversary of the Commence ment
# Date thereafter by an amount equal to the annual rate of one and a half percent (1.5%).

# %%
len(text)
# Out:
# 62168

# %%
len(summary)
# Out:
# 12730

# %%
text_num_of_words =0
summary_num_of_words=0
for i in text:
    if((i==' 'or i=='\n')):
        text_num_of_words=text_num_of_words+1
for i in summary:
    if((i==' 'or i=='\n')):
        summary_num_of_words=summary_num_of_words+1

# %%
print(text_num_of_words)
print(summary_num_of_words)
# Out:
# 11970
# 2237
